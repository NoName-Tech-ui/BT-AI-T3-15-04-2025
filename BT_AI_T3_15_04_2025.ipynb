# %% [markdown]
# <a href="https://colab.research.google.com/github/NoName-Tech-ui/BT-AI-T3-15-04-2025/blob/main/BT_AI_T3_15_04_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

emotion_path = '/content/drive/MyDrive/AI/emotion_dataset'
face_dataset_path = '/content/drive/MyDrive/AI/face_dataset'

known_persons = [folder.replace('_', ' ') for folder in os.listdir(face_dataset_path)
                 if os.path.isdir(os.path.join(face_dataset_path, folder))]

person_id_to_name = {
    'ha': 'Hà Phương',
    'thanhvy': 'Thanh Vy',
    'nhung': 'Nhung',
    'huyen': 'Huyền',
}

images, emotion_labels, person_names = [], [], []

for folder in os.listdir(emotion_path):
    folder_path = os.path.join(emotion_path, folder)
    if os.path.isdir(folder_path):
        try:
            person = folder.split('_')[0]
            emotion = folder.split('_')[1]
        except:
            continue
        for file in os.listdir(folder_path):
            if file.lower().endswith(('jpg', 'png', 'jpeg')):
                img = cv2.imread(os.path.join(folder_path, file))
                img = cv2.resize(img, (100, 100)).astype('float32') / 255.0
                images.append(img)
                emotion_labels.append(emotion)
                person_names.append(person)

le_emotion = LabelEncoder()
emotion_encoded = le_emotion.fit_transform(emotion_labels)
emotion_cat = to_categorical(emotion_encoded)

X_train, X_test, y_train, y_test = train_test_split(np.array(images), emotion_cat, test_size=0.2, random_state=42)


model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(100,100,3)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(emotion_cat.shape[1], activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))


def predict_emotion_with_name(image_path):
    img = cv2.imread(image_path)
    img_resized = cv2.resize(img, (100,100)).astype('float32') / 255.0
    img_input = np.expand_dims(img_resized, axis=0)

    prediction = model.predict(img_input)
    predicted_emotion = le_emotion.inverse_transform([np.argmax(prediction)])[0]

    folder_name = os.path.basename(os.path.dirname(image_path))
    person_raw = folder_name.split('_')[0]

    final_name = person_id_to_name.get(person_raw.lower(), person_raw)

    img_display = cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB)
    plt.imshow(img_display)
    plt.title(f'{final_name} đang cảm thấy {predicted_emotion.upper()}')
    plt.axis('off')
    plt.show()
    print(f'{final_name} đang cảm thấy {predicted_emotion.upper()}')
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.3525 - loss: 1.6305 - val_accuracy: 0.2308 - val_loss: 1.4735
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 584ms/step - accuracy: 0.4073 - loss: 1.3639 - val_accuracy: 0.3846 - val_loss: 1.1190
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 389ms/step - accuracy: 0.3891 - loss: 1.1609 - val_accuracy: 0.3846 - val_loss: 1.1373
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 394ms/step - accuracy: 0.5274 - loss: 0.9925 - val_accuracy: 0.3846 - val_loss: 1.1251
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 429ms/step - accuracy: 0.4700 - loss: 1.0010 - val_accuracy: 0.3846 - val_loss: 1.0541
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - accuracy: 0.4596 - loss: 0.9822 - val_accuracy: 0.3846 - val_loss: 1.0370
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step - accuracy: 0.5300 - loss: 0.9461 - val_accuracy: 0.3846 - val_loss: 1.0300
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 357ms/step - accuracy: 0.5927 - loss: 0.8214 - val_accuracy: 0.3077 - val_loss: 1.0271
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - accuracy: 0.6162 - loss: 0.7960 - val_accuracy: 0.4615 - val_loss: 1.0103
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 348ms/step - accuracy: 0.6867 - loss: 0.7252 - val_accuracy: 0.3846 - val_loss: 0.9989
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 361ms/step - accuracy: 0.8276 - loss: 0.6128 - val_accuracy: 0.4615 - val_loss: 1.0377
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 624ms/step - accuracy: 0.8068 - loss: 0.5134 - val_accuracy: 0.3846 - val_loss: 1.1350
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step - accuracy: 0.8460 - loss: 0.4513 - val_accuracy: 0.3846 - val_loss: 1.0716
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 0.9034 - loss: 0.3518 - val_accuracy: 0.3846 - val_loss: 1.1414
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - accuracy: 0.8772 - loss: 0.3330 - val_accuracy: 0.4615 - val_loss: 1.2758
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 381ms/step - accuracy: 0.9530 - loss: 0.2793 - val_accuracy: 0.4615 - val_loss: 1.3333
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 373ms/step - accuracy: 0.9869 - loss: 0.1816 - val_accuracy: 0.4615 - val_loss: 1.4495
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 386ms/step - accuracy: 0.9400 - loss: 0.1958 - val_accuracy: 0.4615 - val_loss: 1.5280
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 361ms/step - accuracy: 0.9634 - loss: 0.1674 - val_accuracy: 0.4615 - val_loss: 1.5123
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step - accuracy: 0.9530 - loss: 0.1550 - val_accuracy: 0.5385 - val_loss: 1.6195
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 385ms/step - accuracy: 0.9869 - loss: 0.1419 - val_accuracy: 0.4615 - val_loss: 1.7431
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 385ms/step - accuracy: 0.9739 - loss: 0.1355 - val_accuracy: 0.3846 - val_loss: 1.6570
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 440ms/step - accuracy: 0.9765 - loss: 0.0909 - val_accuracy: 0.4615 - val_loss: 1.5426
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 585ms/step - accuracy: 0.9869 - loss: 0.0905 - val_accuracy: 0.5385 - val_loss: 1.6857
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 666ms/step - accuracy: 0.9765 - loss: 0.1169 - val_accuracy: 0.4615 - val_loss: 2.1090
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - accuracy: 0.9765 - loss: 0.0563 - val_accuracy: 0.4615 - val_loss: 2.5485
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step - accuracy: 0.9530 - loss: 0.1380 - val_accuracy: 0.5385 - val_loss: 2.1308
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 379ms/step - accuracy: 0.9530 - loss: 0.0730 - val_accuracy: 0.4615 - val_loss: 2.1985
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 389ms/step - accuracy: 1.0000 - loss: 0.0197 - val_accuracy: 0.4615 - val_loss: 2.3333
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 445ms/step - accuracy: 0.9869 - loss: 0.0701 - val_accuracy: 0.4615 - val_loss: 2.2833
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 375ms/step - accuracy: 0.9869 - loss: 0.0362 - val_accuracy: 0.5385 - val_loss: 2.3005
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 369ms/step - accuracy: 1.0000 - loss: 0.0384 - val_accuracy: 0.5385 - val_loss: 2.5046
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 367ms/step - accuracy: 1.0000 - loss: 0.0192 - val_accuracy: 0.5385 - val_loss: 2.7806
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 367ms/step - accuracy: 1.0000 - loss: 0.0327 - val_accuracy: 0.4615 - val_loss: 2.9065
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 623ms/step - accuracy: 0.9634 - loss: 0.0585 - val_accuracy: 0.5385 - val_loss: 2.7739
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step - accuracy: 1.0000 - loss: 0.0312 - val_accuracy: 0.5385 - val_loss: 2.5488
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 355ms/step - accuracy: 1.0000 - loss: 0.0242 - val_accuracy: 0.5385 - val_loss: 2.4728
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 444ms/step - accuracy: 1.0000 - loss: 0.0231 - val_accuracy: 0.5385 - val_loss: 2.5524
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 374ms/step - accuracy: 1.0000 - loss: 0.0222 - val_accuracy: 0.5385 - val_loss: 2.7406
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step - accuracy: 1.0000 - loss: 0.0245 - val_accuracy: 0.5385 - val_loss: 2.9569
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 372ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.5385 - val_loss: 3.0715
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 375ms/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 0.5385 - val_loss: 3.0433
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 445ms/step - accuracy: 1.0000 - loss: 0.0141 - val_accuracy: 0.5385 - val_loss: 3.0724
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 376ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.5385 - val_loss: 3.1916
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 361ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.5385 - val_loss: 3.3604
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.5385 - val_loss: 3.1476
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.5385 - val_loss: 2.9897
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 659ms/step - accuracy: 1.0000 - loss: 0.0258 - val_accuracy: 0.4615 - val_loss: 2.8289
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 650ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.4615 - val_loss: 2.7675
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.4615 - val_loss: 2.7583

# %%
test_image = '/content/drive/MyDrive/AI/emotion_dataset/ha_happy/2.jpg'
predict_emotion_with_name(test_image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Hà Phương đang cảm thấy HAPPY

# %%
test_image = '/content/drive/MyDrive/AI/emotion_dataset/thanhvy_wow/IMG_5922.jpg'
predict_emotion_with_name(test_image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Thanh Vy đang cảm thấy WOW

# %%
test_image = '/content/drive/MyDrive/AI/emotion_dataset/nhung_wow/img2.jpg'
predict_emotion_with_name(test_image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Nhung đang cảm thấy WOW

# %%
test_image = '/content/drive/MyDrive/AI/emotion_dataset/huyen_happy/491024595_935344941868573_3553462349612724959_n.jpg'
predict_emotion_with_name(test_image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Huyền đang cảm thấy HAPPY
